# %%
import pandas as pd
data=pd.read_excel("D:\\Python codes\\Python File\\PANDAS READ FILE WITH  DATA\\Sample - Superstore.xls")
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Downloads'

# %%
os.chdir("D:\\Python codes\\Python File\\PANDAS READ FILE WITH  DATA")

# %%
data1=pd.read_excel("Sample - Superstore.xls",sheet_name="Returns")
data1.head(10)
# Out:
#   Returned        Order ID
# 0      Yes  CA-2017-153822
# 1      Yes  CA-2017-129707
# 2      Yes  CA-2014-152345
# 3      Yes  CA-2015-156440
# 4      Yes  US-2017-155999
# 5      Yes  CA-2014-157924
# 6      Yes  CA-2017-131807
# 7      Yes  CA-2016-124527
# 8      Yes  CA-2017-135692
# 9      Yes  CA-2014-123225

# %%
data2=pd.read_excel("Sample - Superstore.xls",sheet_name="People")
data2.head(10)
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
a=pd.DataFrame(data)

# %%
b=pd.DataFrame(data1)

# %%
data3=pd.merge(a,b,on="Order ID")

# %%
data3.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0      19  CA-2014-143336 2014-08-27 2014-09-01  Second Class    ZD-21925
# 1      20  CA-2014-143336 2014-08-27 2014-09-01  Second Class    ZD-21925
# 2      21  CA-2014-143336 2014-08-27 2014-09-01  Second Class    ZD-21925
# 3      56  CA-2016-111682 2016-06-17 2016-06-18   First Class    TB-21055
# 4      57  CA-2016-111682 2016-06-17 2016-06-18   First Class    TB-21055
#
#         Customer Name   Segment        Country           City  ... Region  \
# 0  Zuschuss Donatelli  Consumer  United States  San Francisco  ...   West
# 1  Zuschuss Donatelli  Consumer  United States  San Francisco  ...   West
# 2  Zuschuss Donatelli  Consumer  United States  San Francisco  ...   West
# 3     Ted Butterfield  Consumer  United States           Troy  ...   East
# 4     Ted Butterfield  Consumer  United States           Troy  ...   East
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#Which Customer has maximum ordered

# %%
data4=data3["Customer ID"].max()

# %%
data4
# Out:
# 'ZD-21925'

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 0 to 799
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         800 non-null    int64
#  1   Order ID       800 non-null    object
#  2   Order Date     800 non-null    datetime64[ns]
#  3   Ship Date      800 non-null    datetime64[ns]
#  4   Ship Mode      800 non-null    object
#  5   Customer ID    800 non-null    object
#  6   Customer Name  800 non-null    object
#  7   Segment        800 non-null    object
#  8   Country        800 non-null    object
#  9   City           800 non-null    object
#  10  State          800 non-null    object
#  11  Postal Code    800 non-null    int64
#  12  Region         800 non-null    object
#  13  Product ID     800 non-null    object
#  14  Category       800 non-null    object
#  15  Sub-Category   800 non-null    object
#  16  Product Name   800 non-null    object
# ...

# %%
data3["Ship Mode"].value_counts()
# Out:
# Standard Class    450
# First Class       152
# Second Class      134
# Same Day           64
# Name: Ship Mode, dtype: int64

# %%
df=pd.DataFrame(data)

# %%
pd.crosstab([df.Country,df.State],[df.Quantity,df.Discount])
# Out:
# Quantity                             1                                      \
# Discount                           0.00 0.10 0.15 0.20 0.30 0.32 0.40 0.45
# Country       State
# United States Alabama                 5    0    0    0    0    0    0    0
#               Arizona                 0    0    0   16    0    0    0    0
#               Arkansas                2    0    0    0    0    0    0    0
#               California            112    0    4   52    0    0    0    0
#               Colorado                0    0    0   15    0    0    0    0
#               Connecticut             9    0    0    0    2    0    0    0
#               Delaware                6    0    0    0    0    0    0    0
#               District of Columbia    0    0    0    0    0    0    0    0
#               Florida                 0    0    0   28    0    0    0    1
#               Georgia                18    0    0    0    0    0    0    0
# ...

# %%
c=data3.columns

# %%
df.pivot_table(index="Ship Mode",columns="State")
# Out:
#                Discount                                                      \
# State           Alabama   Arizona Arkansas California  Colorado Connecticut
# Ship Mode
# First Class         0.0  0.314286      0.0   0.075311  0.309091    0.000000
# Same Day            0.0  0.356250      0.0   0.069328  0.366667    0.030000
# Second Class        0.0  0.266667      0.0   0.073165  0.315152    0.000000
# Standard Class      0.0  0.301439      0.0   0.072275  0.317172    0.007143
#
#                                                                  ...  \
# State           Delaware District of Columbia   Florida Georgia  ...
# Ship Mode                                                        ...
# First Class     0.016667                  NaN  0.309259     0.0  ...
# Same Day        0.000000                  NaN  0.235714     0.0  ...
# Second Class    0.000000                  0.0  0.263433     0.0  ...
# Standard Class  0.005000                  0.0  0.314957     0.0  ...
#
# ...

# %%
df.pivot_table(index="Segment",columns="Sales",margins=True,aggfunc="max")
# Out:
#                        Category                                        \
# Sales       0.44399999999999995 0.5559999999999998 0.8359999999999997
# Segment
# Consumer        Office Supplies                NaN                NaN
# Corporate                   NaN    Office Supplies    Office Supplies
# Home Office                 NaN                NaN                NaN
# All             Office Supplies    Office Supplies    Office Supplies
#
#                                                                       \
# Sales       0.8520000000000001 0.8759999999999998 0.8979999999999998
# Segment
# Consumer       Office Supplies                NaN                NaN
# Corporate                  NaN    Office Supplies    Office Supplies
# Home Office                NaN                NaN                NaN
# All            Office Supplies    Office Supplies    Office Supplies
#
#                                                                \
# ...

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
p=sorted(c)
p
# Out:
# ['Category',
#  'City',
#  'Country',
#  'Customer ID',
#  'Customer Name',
#  'Discount',
#  'Order Date',
#  'Order ID',
#  'Postal Code',
#  'Product ID',
#  'Product Name',
#  'Profit',
#  'Quantity',
#  'Region',
#  'Returned',
#  'Row ID',
#  'Sales',
#  'Segment',
#  'Ship Date',
#  'Ship Mode',
#  'State',
#  'Sub-Category']

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df1=data[["Ship Mode","Sales","Segment"]]

# %%
df1
# Out:
#            Ship Mode     Sales    Segment
# 0       Second Class  261.9600   Consumer
# 1       Second Class  731.9400   Consumer
# 2       Second Class   14.6200  Corporate
# 3     Standard Class  957.5775   Consumer
# 4     Standard Class   22.3680   Consumer
# ...              ...       ...        ...
# 9989    Second Class   25.2480   Consumer
# 9990  Standard Class   91.9600   Consumer
# 9991  Standard Class  258.5760   Consumer
# 9992  Standard Class   29.6000   Consumer
# 9993    Second Class  243.1600   Consumer
#
# [9994 rows x 3 columns]

# %%
#Which Mode has maximum sales:
df1["Ship Mode"][df1["Sales"]==df1["Sales"].max()]
# Out:
# 2697    Standard Class
# Name: Ship Mode, dtype: object

# %%
#Which segment has maximum sales:
df1["Segment"][df1["Sales"]==df1["Sales"].max()]
# Out:
# 2697    Home Office
# Name: Segment, dtype: object

# %%
df1["Segment"].mode()
# Out:
# 0    Consumer
# dtype: object

# %%
df1["Ship Mode"].mode()
# Out:
# 0    Standard Class
# dtype: object

# %%
data1["Returned"].value_counts()
# Out:
# Yes    296
# Name: Returned, dtype: int64

# %%
df=df.set_index("Order Date")

# %%
df
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2015-10-11       4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966 2015-10-18  Standard Class    SO-20335
# ...            ...             ...        ...             ...         ...
# 2014-01-21    9990  CA-2014-110422 2014-01-23    Second Class    TB-21400
# 2017-02-26    9991  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9992  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9993  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-05-04    9994  CA-2017-119914 2017-05-09    Second Class    CC-12220
#
# ...

# %%
# How many Orders ID has been returned:

Retrn1=data1.pivot(index="Order ID",columns="Returned")

# %%
Retrn1
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
pd.crosstab(data3.Segment,[data3.Sales,data3.Discount])
# Out:
# Sales       1.680     1.872     1.938     2.224     2.304         2.376      \
# Discount          0.0       0.7       0.7       0.2       0.8 0.2       0.7
# Segment
# Consumer            1         0         0         0         0   1         0
# Corporate           0         1         1         0         1   0         1
# Home Office         0         0         0         1         0   0         0
#
# Sales       2.508     2.600     2.780      ... 2177.584  2239.936  2254.410   \
# Discount          0.7       0.2       0.0  ...       0.8       0.2       0.1
# Segment                                    ...
# Consumer            1         1         1  ...         1         0         1
# Corporate           0         0         0  ...         0         1         0
# Home Office         0         0         0  ...         0         0         0
#
# Sales       2453.430  2518.290  2548.560  2799.944  2799.960  2888.127   \
# ...

# %%
data3["Returned"][data3["Segment"].value_counts()]
# Out:
# 426    Yes
# 257    Yes
# 117    Yes
# Name: Returned, dtype: object

# %%
data3["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
data3.describe(include="object")
# Out:
#               Order ID       Ship Mode Customer ID Customer Name   Segment  \
# count              800             800         800           800       800
# unique             296               4         247           247         3
# top     CA-2017-100111  Standard Class    SV-20365   Seth Vernon  Consumer
# freq                14             450          14            14       426
#
#               Country         City       State Region       Product ID  \
# count             800          800         800    800              800
# unique              1          119          36      4              648
# top     United States  Los Angeles  California   West  OFF-PA-10001970
# freq              800          117         338    490                4
#
#                Category Sub-Category                Product Name Returned
# count               800          800                         800      800
# unique                3           17                         646        1
# ...

# %%
data3.nunique()
# Out:
# Row ID           800
# Order ID         296
# Order Date       259
# Ship Date        262
# Ship Mode          4
# Customer ID      247
# Customer Name    247
# Segment            3
# Country            1
# City             119
# State             36
# Postal Code      152
# Region             4
# Product ID       648
# Category           3
# Sub-Category      17
# Product Name     646
# Sales            733
# Quantity          14
# Discount          11
# Profit           757
# Returned           1
# dtype: int64

# %%
pd.crosstab(data3["Category"],[data3["Sub-Category"]])
# Out:
# Sub-Category     Accessories  Appliances  Art  Binders  Bookcases  Chairs  \
# Category
# Furniture                  0           0    0        0         16      53
# Office Supplies            0          40   47      137          0       0
# Technology                61           0    0        0          0       0
#
# Sub-Category     Copiers  Envelopes  Fasteners  Furnishings  Labels  Machines  \
# Category
# Furniture              0          0          0           72       0         0
# Office Supplies        0         13         19            0      21         0
# Technology             5          0          0            0       0        13
#
# Sub-Category     Paper  Phones  Storage  Supplies  Tables
# Category
# Furniture            0       0        0         0      30
# Office Supplies    123       0       57        16       0
# Technology           0      77        0         0       0

# %%
data3["Sls_aftr_prft"]=data3["Sales"]-data3["Profit"]

# %%
data3
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        19  CA-2014-143336 2014-08-27 2014-09-01    Second Class    ZD-21925
# 1        20  CA-2014-143336 2014-08-27 2014-09-01    Second Class    ZD-21925
# 2        21  CA-2014-143336 2014-08-27 2014-09-01    Second Class    ZD-21925
# 3        56  CA-2016-111682 2016-06-17 2016-06-18     First Class    TB-21055
# 4        57  CA-2016-111682 2016-06-17 2016-06-18     First Class    TB-21055
# ..      ...             ...        ...        ...             ...         ...
# 795    9958  US-2014-143287 2014-11-11 2014-11-17  Standard Class    KN-16705
# 796    9959  US-2014-143287 2014-11-11 2014-11-17  Standard Class    KN-16705
# 797    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 798    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 799    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
#
# ...

# %%
data3.reset_index("Order Date",inplace=True)

# %%
data3
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2014-08-27      19  CA-2014-143336 2014-09-01    Second Class    ZD-21925
# 2014-08-27      20  CA-2014-143336 2014-09-01    Second Class    ZD-21925
# 2014-08-27      21  CA-2014-143336 2014-09-01    Second Class    ZD-21925
# 2016-06-17      56  CA-2016-111682 2016-06-18     First Class    TB-21055
# 2016-06-17      57  CA-2016-111682 2016-06-18     First Class    TB-21055
# ...            ...             ...        ...             ...         ...
# 2014-11-11    9958  US-2014-143287 2014-11-17  Standard Class    KN-16705
# 2014-11-11    9959  US-2014-143287 2014-11-17  Standard Class    KN-16705
# 2017-02-26    9991  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9992  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9993  CA-2017-121258 2017-03-03  Standard Class    DB-13060
#
# ...

# %%
# Summary of last two years in which are checking how much max sales increasing in 2016 and how much sales are increasing from 2016 to 2017:

# %%
data.set_index("Order Date",inplace=True)

# %%
data
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2015-10-11       4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966 2015-10-18  Standard Class    SO-20335
# ...            ...             ...        ...             ...         ...
# 2014-01-21    9990  CA-2014-110422 2014-01-23    Second Class    TB-21400
# 2017-02-26    9991  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9992  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9993  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-05-04    9994  CA-2017-119914 2017-05-09    Second Class    CC-12220
#
# ...

# %%
data_2016=data.loc["2016-01-02":"2016-12-31"]

# %%
data_2016
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2016-12-05      14  CA-2016-161389 2016-12-10  Standard Class    IM-15070
# 2016-12-09      22  CA-2016-137330 2016-12-13  Standard Class    KB-16585
# ...            ...             ...        ...             ...         ...
# 2016-12-06    9979  US-2016-103674 2016-12-10  Standard Class    AP-10720
# 2016-12-06    9980  US-2016-103674 2016-12-10  Standard Class    AP-10720
# 2016-09-22    9983  US-2016-157728 2016-09-28  Standard Class    RC-19960
# 2016-09-22    9984  US-2016-157728 2016-09-28  Standard Class    RC-19960
# 2016-09-29    9987  CA-2016-125794 2016-10-03  Standard Class    ML-17410
#
# ...

# %%
data_2017=data.loc["2017-01-01":"2017-12-30"]

# %%
data_2017
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-04-15      13  CA-2017-114412 2017-04-20  Standard Class    AA-10480
# 2017-07-16      24  US-2017-156909 2017-07-18    Second Class    SF-20065
# 2017-10-19      35  CA-2017-107727 2017-10-23    Second Class    MA-17560
# 2017-09-10      42  CA-2017-120999 2017-09-15  Standard Class    LC-16930
# 2017-09-19      44  CA-2017-139619 2017-09-23  Standard Class    ES-14080
# ...            ...             ...        ...             ...         ...
# 2017-11-17    9989  CA-2017-163629 2017-11-21  Standard Class    RA-19885
# 2017-02-26    9991  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9992  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9993  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-05-04    9994  CA-2017-119914 2017-05-09    Second Class    CC-12220
#
# ...

# %%
Mx_Sls_2016=data_2016["Sales"].max()

# %%
Mx_Sls_2016
# Out:
# 17499.949999999997

# %%
Mx_Prft_2016=data_2016["Profit"].max()

# %%
Mx_Prft_2016
# Out:
# 8399.975999999999

# %%
Mx_Sls_2017=data_2017["Sales"].max()

# %%
Mx_Sls_2017
# Out:
# 13999.96

# %%
Mx_Prft_2017=data_2017["Profit"].max()

# %%
Mx_Prft_2017
# Out:
# 6719.980799999999

# %%
diff_16_17_Sls=Mx_Sls_2016-Mx_Sls_2017

# %%
diff_16_17_Sls
# Out:
# 3499.989999999998

# %%
diff_16_17_Prft=Mx_Prft_2016-Mx_Prft_2017

# %%
diff_16_17_Prft
# Out:
# 1679.9951999999994

# %%
data_2015=data.loc["2015-01-01":"2015-12-31"]

# %%
data_2015
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2015-10-11       4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-11-22      15  US-2015-118983 2015-11-26  Standard Class    HP-14815
# 2015-11-22      16  US-2015-118983 2015-11-26  Standard Class    HP-14815
# 2015-09-25      25  CA-2015-106320 2015-09-30  Standard Class    EB-13870
# ...            ...             ...        ...             ...         ...
# 2015-06-28    9971  CA-2015-103772 2015-07-02  Standard Class    MP-17470
# 2015-06-28    9972  CA-2015-103772 2015-07-02  Standard Class    MP-17470
# 2015-09-06    9981  US-2015-151435 2015-09-09    Second Class    SW-20455
# 2015-05-17    9985  CA-2015-100251 2015-05-23  Standard Class    DV-13465
# 2015-05-17    9986  CA-2015-100251 2015-05-23  Standard Class    DV-13465
#
# ...

# %%
Mx_Sls_2015=data_2015["Sales"].max()

# %%
Mx_Sls_2015
# Out:
# 6354.95

# %%
Mx_Prft_2015=data_2015["Profit"].max()

# %%
diff_16_15_Sls=Mx_Sls_2016-Mx_Sls_2015

# %%
diff_16_15_Sls
# Out:
# 11144.999999999996

# %%
diff_16_15_Prft=Mx_Prft_2016-Mx_Prft_2015

# %%
diff_16_15_Prft
# Out:
# 5222.500999999998

# %%
# Now we will check how sales or profit will impact on days deliver to product(difference from oder date to ship date)

# %%
data.reset_index(["Order Date"],inplace=True)

# %%
data
# Out:
#      Order Date  Row ID        Order ID  Ship Date       Ship Mode  \
# 0    2016-11-08       1  CA-2016-152156 2016-11-11    Second Class
# 1    2016-11-08       2  CA-2016-152156 2016-11-11    Second Class
# 2    2016-06-12       3  CA-2016-138688 2016-06-16    Second Class
# 3    2015-10-11       4  US-2015-108966 2015-10-18  Standard Class
# 4    2015-10-11       5  US-2015-108966 2015-10-18  Standard Class
# ...         ...     ...             ...        ...             ...
# 9989 2014-01-21    9990  CA-2014-110422 2014-01-23    Second Class
# 9990 2017-02-26    9991  CA-2017-121258 2017-03-03  Standard Class
# 9991 2017-02-26    9992  CA-2017-121258 2017-03-03  Standard Class
# 9992 2017-02-26    9993  CA-2017-121258 2017-03-03  Standard Class
# 9993 2017-05-04    9994  CA-2017-119914 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
data_ordr=data.set_index("Order Date")

# %%
data_ordr
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2015-10-11       4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966 2015-10-18  Standard Class    SO-20335
# ...            ...             ...        ...             ...         ...
# 2014-01-21    9990  CA-2014-110422 2014-01-23    Second Class    TB-21400
# 2017-02-26    9991  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9992  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9993  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-05-04    9994  CA-2017-119914 2017-05-09    Second Class    CC-12220
#
# ...

# %%
data_ship=data.set_index("Ship Date")

# %%
data_ship
# Out:
#            Order Date  Row ID        Order ID       Ship Mode Customer ID  \
# Ship Date
# 2016-11-11 2016-11-08       1  CA-2016-152156    Second Class    CG-12520
# 2016-11-11 2016-11-08       2  CA-2016-152156    Second Class    CG-12520
# 2016-06-16 2016-06-12       3  CA-2016-138688    Second Class    DV-13045
# 2015-10-18 2015-10-11       4  US-2015-108966  Standard Class    SO-20335
# 2015-10-18 2015-10-11       5  US-2015-108966  Standard Class    SO-20335
# ...               ...     ...             ...             ...         ...
# 2014-01-23 2014-01-21    9990  CA-2014-110422    Second Class    TB-21400
# 2017-03-03 2017-02-26    9991  CA-2017-121258  Standard Class    DB-13060
# 2017-03-03 2017-02-26    9992  CA-2017-121258  Standard Class    DB-13060
# 2017-03-03 2017-02-26    9993  CA-2017-121258  Standard Class    DB-13060
# 2017-05-09 2017-05-04    9994  CA-2017-119914    Second Class    CC-12220
#
# ...

# %%
data_dys=data["Ship Date"]-data["Order Date"]

# %%
data_dys=pd.DataFrame(data_dys)

# %%
data_dys["Days"]=data_dys[0]

# %%
data_dys.drop(0,axis=1,inplace =True)

# %%
data_dys
# Out:
#        Days
# 0    3 days
# 1    3 days
# 2    4 days
# 3    7 days
# 4    7 days
# ...     ...
# 9989 2 days
# 9990 5 days
# 9991 5 days
# 9992 5 days
# 9993 5 days
#
# [9994 rows x 1 columns]

# %%
data_dys["Days"][data["Sales"]==data["Sales"].max()]
# Out:
# 2697   5 days
# Name: Days, dtype: timedelta64[ns]

# %%
data_dys["Days"][data["Sales"]==data["Sales"].min()]
# Out:
# 4101   4 days
# Name: Days, dtype: timedelta64[ns]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data["data_dys"]=(data["Ship Date"]-data["Order Date"]).dt.days

# %%
data["data_dys"]
# Out:
# 0       3
# 1       3
# 2       4
# 3       7
# 4       7
#        ..
# 9989    2
# 9990    5
# 9991    5
# 9992    5
# 9993    5
# Name: data_dys, Length: 9994, dtype: int64

# %%
plt.scatter(data["data_dys"],data["Sales"],c="r",cmap="inferno")
